# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # With periodic timer

# %%
df = pd.read_csv("speedlog_with_timer.csv").plot(x='timestamp', y='speed')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Without regular timer

# %%
df = pd.read_csv("speedlog_without_timer.csv")
df.plot(x='timestamp', y='speed')
# Out:
# <img src="data:image/png;base64,..." width="640">
